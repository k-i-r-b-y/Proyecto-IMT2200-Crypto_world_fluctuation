# %%
from urllib import response
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd
import time
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **WEBSCRAPPING A METACRITIC**

# %%
pages = []
page = 0
for x in range(100):
    pages.append(page)
    page += 2

links = []
for p in pages:
    url = f"https://www.metacritic.com/browse/games/score/metascore/all/all/filtered?page={p}"
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(url, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")

    juegos = soup.find_all("td", {"class": "clamp-summary-wrap"})
    for j in juegos:
        a = j.find("a", {"class": "title"})
        l = a["href"]
        link = (f"http://www.metacritic.com{l}")
        links.append(link)
    time.sleep(0.02)

# %% [markdown]
# WEBSCRAPPING TOTAL

# %%
nombres = []
ratings = []
plataforma = []
rating_user = []
developers = []
date = []
generos = []
resumen = []
clasificacion = []
players = []

for l in links:
    time.sleep(0.02)
    try:
        user_agent = {'User-agent': 'Mozilla/5.0'}
        response = rq.get(l, headers = user_agent)
        soup = BeautifulSoup(response.text, "html.parser")
        a = soup.find_all("div", {"class":"product_title"}) #NOMBRES
        for p in a:
            nombre = (p.find("a").text.strip())
            # nombres.append(p.find("a").text.strip())

        a = soup.find_all("a",{"class": "metascore_anchor"}) #RATINGS
        rating = (a[0].text.strip())
        # ratings.append(a[0].text.strip())

        a = soup.find_all("div", {"class":"product_title"})  #PLATAFORMA
        for p in a:
            plataform = (p.find("span").text.strip())
            # plataforma.append(p.find("span").text.strip())

        a = soup.find_all("a",{"class": "metascore_anchor"})  #RATINGS USERS
        rating_u = (a[1].text.strip())
        # rating_user.append(a[1].text.strip())

        a = soup.find_all("span",{"class": "data"})  #DEVELOPERS
        for p in a:
            developer = (p.find("a").text.strip())
            # developers.append(p.find("a").text.strip())
            break

        a = soup.find_all("li",{"class": "summary_detail release_data"}) #DATE
        for p in a:
            fecha = (p.find("span", {"class":"data"}).text)
            # date.append(p.find("span", {"class":"data"}).text)


        a = soup.find_all("li",{"class": "summary_detail product_genre"}) #GENEROS
        for p in a:
            genero = (p.find("span", {"class":"data"}).text)
            # generos.append(p.find("span", {"class":"data"}).text)


        a = soup.find_all("li",{"class": "summary_detail product_summary"})   #RESUMEN
        for p in a:
            if p.find("span", {"class":"blurb blurb_collapsed"}) == None:
                continue
            else:
                sinopsis = (p.find("span", {"class":"blurb blurb_collapsed"}).text.strip())
                # resumen[contador] = (p.find("span", {"class":"blurb blurb_collapsed"}).text.strip())

            
        for p in a:
            if p.find("span", {"class":"data"}) == None:
                continue
            else:
                sinopsis = (p.find("span", {"class":"data"}).text.strip())
                # resumen[contador] = (p.find("span", {"class":"data"}).text.strip())
        


        a = soup.find_all("li",{"class": "summary_detail product_rating"})     #CLASIFICACION
        for p in a:
            if p.find("span", {"class":"data"}) == None:
                continue
            else:
                restric = (p.find("span", {"class":"data"}).text)
                # clasificacion[contador] = (p.find("span", {"class":"data"}).text)
                

        a = soup.find_all("ul",{"class": "summary_details"})  #N_JUGADORES
        for p in a:
            b = p.find("li", {"class": "summary_detail product_players"})
            if b == None:
                continue
            else:
                c_players = ((b.text.split(":")[1].strip()))
                # players[contador] = ((b.text.split(":")[1].strip()))
        
        nombres.append(nombre)
        ratings.append(rating)
        plataforma.append(plataform)
        rating_user.append(rating_u)
        developers.append(developer)
        date.append(fecha)
        generos.append(genero)
        resumen.append(sinopsis)  ###
        clasificacion.append(restric)
        players.append(c_players)

        
    except:
        continue

# %%
df_games = pd.DataFrame()
df_games["Nombre"] = nombres
df_games["Rating_Meta"] = ratings
df_games["Rating_Usuarios"] = rating_user
df_games["Plataforma"] = plataforma
df_games["Developer"] = developers
df_games["Fecha"] = date
df_games["Genero"] = generos
df_games["Resumen"] = resumen
df_games["N_jugadores"] = players
df_games["Clasificacion"] = clasificacion
df_games
# Out:
#                                             Nombre Rating_Meta  \
# 0             The Legend of Zelda: Ocarina of Time          99
# 1                         Tony Hawk's Pro Skater 2          98
# 2                              Grand Theft Auto IV          98
# 3                                      SoulCalibur          98
# 4                              Grand Theft Auto IV          98
# ...                                            ...         ...
# 9937                        Vroom in the Night Sky          17
# 9938           Leisure Suit Larry: Box Office Bust          17
# 9939                                         Yaris          17
# 9940                     Ride to Hell: Retribution          16
# 9941  Family Party: 30 Great Games Obstacle Arcade          11
#
#      Rating_Usuarios     Plataforma               Developer         Fecha  \
# 0                9.1    Nintendo 64                Nintendo  Nov 23, 1998
# 1                7.4    PlayStation              Activision  Sep 20, 2000
# 2                7.8  PlayStation 3          Rockstar Games  Apr 29, 2008
# 3                8.4      Dreamcast                   Namco  Sep  8, 1999
# 4                8.0       Xbox 360          Rockstar Games  Apr 29, 2008
# ...              ...            ...                     ...           ...
# 9937             3.2         Switch                 Poisoft  Apr  5, 2017
# 9938             1.9  PlayStation 3                  Funsta  May  5, 2009
# 9939             4.4       Xbox 360  Backbone Entertainment  Oct 10, 2007
# 9940             1.4             PC             Deep Silver  Jun 24, 2013
# 9941             2.6          Wii U             D3Publisher  Dec  4, 2012
#
#                 Genero                                            Resumen  \
# 0     Action Adventure  As a young boy, Link is tricked by Ganondorf, ...
# 1               Sports  As most major publishers' development efforts ...
# 2     Action Adventure  [Metacritic's 2008 PS3 Game of the Year; Also ...
# 3               Action  This is a tale of souls and swords, transcendi...
# 4     Action Adventure  [Metacritic's 2008 Xbox 360 Game of the Year; ...
# ...                ...                                                ...
# 9937            Sports  Vroom in the night sky is a magical bike actio...
# 9938  Action Adventure  The Leisure Suit Larry: Box Office Bust video ...
# 9939           Driving  [Xbox Live Arcade]  Hop into a Toyota Yaris an...
# 9940           Driving  The game is set in the last years of the roari...
# 9941     Miscellaneous  Family Party: 30 Great Games Obstacle Arcade b...
#
#                 N_jugadores Clasificacion
# 0                  1 Player             E
# 1                       1-2             T
# 2                  1 Player             M
# 3                       1-2             T
# 4                  1 Player             M
# ...                     ...           ...
# 9937  No Online Multiplayer             E
# 9938  No Online Multiplayer             M
# 9939              2  Online          E10+
# 9940              2  Online             M
# 9941  No Online Multiplayer             E
#
# [9942 rows x 10 columns]

# %% [markdown]
# Almacenamos los datos localmente:

# %%
df_games.to_csv("datos_metacritic.csv", index=False)

# %% [markdown]
# **##################################################**

# %%
df_games = pd.read_csv("datos_metacritic.csv")
df_games
# Out:
#                                             Nombre Rating_Meta  \
# 0             The Legend of Zelda: Ocarina of Time          99
# 1                         Tony Hawk's Pro Skater 2          98
# 2                              Grand Theft Auto IV          98
# 3                                      SoulCalibur          98
# 4                              Grand Theft Auto IV          98
# ...                                            ...         ...
# 9937                        Vroom in the Night Sky          17
# 9938           Leisure Suit Larry: Box Office Bust          17
# 9939                                         Yaris          17
# 9940                     Ride to Hell: Retribution          16
# 9941  Family Party: 30 Great Games Obstacle Arcade          11
#
#      Rating_Usuarios     Plataforma               Developer         Fecha  \
# 0                9.1    Nintendo 64                Nintendo  Nov 23, 1998
# 1                7.4    PlayStation              Activision  Sep 20, 2000
# 2                7.8  PlayStation 3          Rockstar Games  Apr 29, 2008
# 3                8.4      Dreamcast                   Namco  Sep  8, 1999
# 4                8.0       Xbox 360          Rockstar Games  Apr 29, 2008
# ...              ...            ...                     ...           ...
# 9937             3.2         Switch                 Poisoft  Apr  5, 2017
# 9938             1.9  PlayStation 3                  Funsta  May  5, 2009
# 9939             4.4       Xbox 360  Backbone Entertainment  Oct 10, 2007
# 9940             1.4             PC             Deep Silver  Jun 24, 2013
# 9941             2.6          Wii U             D3Publisher  Dec  4, 2012
#
#                 Genero                                            Resumen  \
# 0     Action Adventure  As a young boy, Link is tricked by Ganondorf, ...
# 1               Sports  As most major publishers' development efforts ...
# 2     Action Adventure  [Metacritic's 2008 PS3 Game of the Year; Also ...
# 3               Action  This is a tale of souls and swords, transcendi...
# 4     Action Adventure  [Metacritic's 2008 Xbox 360 Game of the Year; ...
# ...                ...                                                ...
# 9937            Sports  Vroom in the night sky is a magical bike actio...
# 9938  Action Adventure  The Leisure Suit Larry: Box Office Bust video ...
# 9939           Driving  [Xbox Live Arcade]  Hop into a Toyota Yaris an...
# 9940           Driving  The game is set in the last years of the roari...
# 9941     Miscellaneous  Family Party: 30 Great Games Obstacle Arcade b...
#
#                 N_jugadores Clasificacion
# 0                  1 Player             E
# 1                       1-2             T
# 2                  1 Player             M
# 3                       1-2             T
# 4                  1 Player             M
# ...                     ...           ...
# 9937  No Online Multiplayer             E
# 9938  No Online Multiplayer             M
# 9939              2  Online          E10+
# 9940              2  Online             M
# 9941  No Online Multiplayer             E
#
# [9942 rows x 10 columns]

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9942 entries, 0 to 9941
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre           9942 non-null   object
#  1   Rating_Meta      9942 non-null   object
#  2   Rating_Usuarios  9942 non-null   object
#  3   Plataforma       9942 non-null   object
#  4   Developer        9942 non-null   object
#  5   Fecha            9942 non-null   object
#  6   Genero           9942 non-null   object
#  7   Resumen          9942 non-null   object
#  8   N_jugadores      9936 non-null   object
#  9   Clasificacion    9942 non-null   object
# dtypes: object(10)
# memory usage: 776.8+ KB

# %%
df_games = df_games[df_games["Fecha"]!= "TBA - Early Access"] #eliminamos valor erroneo de fecha
df_games = df_games[df_games["Rating_Meta"]!= 'tbd'] #Valores no utiles en el analisis
df_games = df_games[df_games["Rating_Usuarios"]!= 'tbd']

# %%
categorias = ["float", "float", "category", "category", "category", "category"]
columnas = ["Rating_Meta", "Rating_Usuarios", "N_jugadores",
            "Clasificacion", "Plataforma", "Genero"]

df_games["Fecha"] = pd.to_datetime(df_games["Fecha"])

n = 0
for col in columnas:
    try:
        df_games[col] = df_games[col].astype(categorias[n])  ####Arreglar errores
        n+=1
    except:
        print(col)
        continue

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9264 entries, 0 to 9941
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre           9264 non-null   object
#  1   Rating_Meta      9264 non-null   float64
#  2   Rating_Usuarios  9264 non-null   float64
#  3   Plataforma       9264 non-null   category
#  4   Developer        9264 non-null   object
#  5   Fecha            9264 non-null   datetime64[ns]
#  6   Genero           9264 non-null   category
#  7   Resumen          9264 non-null   object
#  8   N_jugadores      9258 non-null   category
#  9   Clasificacion    9264 non-null   category
# dtypes: category(4), datetime64[ns](1), float64(2), object(3)
# memory usage: 548.8+ KB

# %%
df_games
# Out:
#                                             Nombre  Rating_Meta  \
# 0             The Legend of Zelda: Ocarina of Time         99.0
# 1                         Tony Hawk's Pro Skater 2         98.0
# 2                              Grand Theft Auto IV         98.0
# 3                                      SoulCalibur         98.0
# 4                              Grand Theft Auto IV         98.0
# ...                                            ...          ...
# 9937                        Vroom in the Night Sky         17.0
# 9938           Leisure Suit Larry: Box Office Bust         17.0
# 9939                                         Yaris         17.0
# 9940                     Ride to Hell: Retribution         16.0
# 9941  Family Party: 30 Great Games Obstacle Arcade         11.0
#
#       Rating_Usuarios     Plataforma               Developer      Fecha  \
# 0                 9.1    Nintendo 64                Nintendo 1998-11-23
# 1                 7.4    PlayStation              Activision 2000-09-20
# 2                 7.8  PlayStation 3          Rockstar Games 2008-04-29
# 3                 8.4      Dreamcast                   Namco 1999-09-08
# 4                 8.0       Xbox 360          Rockstar Games 2008-04-29
# ...               ...            ...                     ...        ...
# 9937              3.2         Switch                 Poisoft 2017-04-05
# 9938              1.9  PlayStation 3                  Funsta 2009-05-05
# 9939              4.4       Xbox 360  Backbone Entertainment 2007-10-10
# 9940              1.4             PC             Deep Silver 2013-06-24
# 9941              2.6          Wii U             D3Publisher 2012-12-04
#
#                 Genero                                            Resumen  \
# 0     Action Adventure  As a young boy, Link is tricked by Ganondorf, ...
# 1               Sports  As most major publishers' development efforts ...
# 2     Action Adventure  [Metacritic's 2008 PS3 Game of the Year; Also ...
# 3               Action  This is a tale of souls and swords, transcendi...
# 4     Action Adventure  [Metacritic's 2008 Xbox 360 Game of the Year; ...
# ...                ...                                                ...
# 9937            Sports  Vroom in the night sky is a magical bike actio...
# 9938  Action Adventure  The Leisure Suit Larry: Box Office Bust video ...
# 9939           Driving  [Xbox Live Arcade]  Hop into a Toyota Yaris an...
# 9940           Driving  The game is set in the last years of the roari...
# 9941     Miscellaneous  Family Party: 30 Great Games Obstacle Arcade b...
#
#                 N_jugadores Clasificacion
# 0                  1 Player             E
# 1                       1-2             T
# 2                  1 Player             M
# 3                       1-2             T
# 4                  1 Player             M
# ...                     ...           ...
# 9937  No Online Multiplayer             E
# 9938  No Online Multiplayer             M
# 9939              2  Online          E10+
# 9940              2  Online             M
# 9941  No Online Multiplayer             E
#
# [9264 rows x 10 columns]

# %% [markdown]
# A efectos de igualar la escala de rating entre "Rating_Meta y "Rating_usuarios" dividiremos "Rating_Meta" por 10

# %%
df_games["Rating_Meta"] = df_games["Rating_Meta"] / 10
df_games
# Out:
#                                             Nombre  Rating_Meta  \
# 0             The Legend of Zelda: Ocarina of Time          9.9
# 1                         Tony Hawk's Pro Skater 2          9.8
# 2                              Grand Theft Auto IV          9.8
# 3                                      SoulCalibur          9.8
# 4                              Grand Theft Auto IV          9.8
# ...                                            ...          ...
# 9937                        Vroom in the Night Sky          1.7
# 9938           Leisure Suit Larry: Box Office Bust          1.7
# 9939                                         Yaris          1.7
# 9940                     Ride to Hell: Retribution          1.6
# 9941  Family Party: 30 Great Games Obstacle Arcade          1.1
#
#       Rating_Usuarios     Plataforma               Developer      Fecha  \
# 0                 9.1    Nintendo 64                Nintendo 1998-11-23
# 1                 7.4    PlayStation              Activision 2000-09-20
# 2                 7.8  PlayStation 3          Rockstar Games 2008-04-29
# 3                 8.4      Dreamcast                   Namco 1999-09-08
# 4                 8.0       Xbox 360          Rockstar Games 2008-04-29
# ...               ...            ...                     ...        ...
# 9937              3.2         Switch                 Poisoft 2017-04-05
# 9938              1.9  PlayStation 3                  Funsta 2009-05-05
# 9939              4.4       Xbox 360  Backbone Entertainment 2007-10-10
# 9940              1.4             PC             Deep Silver 2013-06-24
# 9941              2.6          Wii U             D3Publisher 2012-12-04
#
#                 Genero                                            Resumen  \
# 0     Action Adventure  As a young boy, Link is tricked by Ganondorf, ...
# 1               Sports  As most major publishers' development efforts ...
# 2     Action Adventure  [Metacritic's 2008 PS3 Game of the Year; Also ...
# 3               Action  This is a tale of souls and swords, transcendi...
# 4     Action Adventure  [Metacritic's 2008 Xbox 360 Game of the Year; ...
# ...                ...                                                ...
# 9937            Sports  Vroom in the night sky is a magical bike actio...
# 9938  Action Adventure  The Leisure Suit Larry: Box Office Bust video ...
# 9939           Driving  [Xbox Live Arcade]  Hop into a Toyota Yaris an...
# 9940           Driving  The game is set in the last years of the roari...
# 9941     Miscellaneous  Family Party: 30 Great Games Obstacle Arcade b...
#
#                 N_jugadores Clasificacion
# 0                  1 Player             E
# 1                       1-2             T
# 2                  1 Player             M
# 3                       1-2             T
# 4                  1 Player             M
# ...                     ...           ...
# 9937  No Online Multiplayer             E
# 9938  No Online Multiplayer             M
# 9939              2  Online          E10+
# 9940              2  Online             M
# 9941  No Online Multiplayer             E
#
# [9264 rows x 10 columns]

# %% [markdown]
# ¿Como se diferencia el rating de criticos al rating dado por los usuarios?

# %%
fig, (ax, ax2) = plt.subplots(1,2, figsize=(30,12))

sns.boxplot(data=df_games,y='Rating_Usuarios', width=0.6, ax=ax)
sns.boxplot(data=df_games,y='Rating_Meta', width=0.6, ax=ax2)
# Out:
# <AxesSubplot:ylabel='Rating_Meta'>

# %% [markdown]
# Hay valores muy grandes para tener sentido en "Rating_usuarios" (max calificacion usuarios = 10)

# %%
df_games = df_games[df_games["Rating_Usuarios"] <= 10]

# %%
fig, (ax, ax2) = plt.subplots(1,2, figsize=(30,12))

sns.boxplot(data=df_games,y='Rating_Usuarios', width=0.6, ax=ax)
sns.boxplot(data=df_games,y='Rating_Meta', width=0.6, ax=ax2)
# Out:
# <AxesSubplot:ylabel='Rating_Meta'>

# %%
lista_generos_juegos = list(df_games['Genero'])
#lista_generos_juegos
def obten_numeros_unicos(lista_generos_juegos):

    lista_de_generos_unicos = []

    generos_unicos = set(lista_generos_juegos)

    for genero in generos_unicos:
        lista_de_generos_unicos.append(genero)

    return lista_de_generos_unicos

# %%
lista_nueva=obten_numeros_unicos(lista_generos_juegos)
#len(lista_nueva)

# %%
cant_repe_generos=[]
for i in lista_nueva:
    cant_repe_generos.append(lista_generos_juegos.count(i))

#cant_repe_generos

# %%
plt.figure(figsize=(12,6))
plt.bar(lista_nueva, cant_repe_generos)
plt.title('Genero y su repeticion')

plt.ylim(0,3200
        )

plt.xlabel(1)


plt.xticks(rotation=90)
#plt.yticks(rotation=45)
plt.show()
plt.close('all')

# %%
generos2=obten_numeros_unicos(lista_generos_juegos)
drop=["Strategy","Action","Adventure"
      ,"Action","Miscellaneous","Role-Playing"
      ,"Adventure","Sports","Driving","Simulation"]
for i in drop:
    generos2.remove(i)
    
print(generos2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [99], in <cell line: 5>()
#       2 drop=["Strategy","Action","Adventure"
#       3       ,"Action","Miscellaneous","Role-Playing"
#       4       ,"Adventure","Sports","Driving","Simulation"]
#       5 for i in drop:
# ----> 6     generos2.remove(i)
#       8 print(generos2)
#
# ValueError: list.remove(x): x not in list

# %%
generos2=obten_numeros_unicos(lista_generos_juegos)
drop=["Strategy","Action","Adventure"
      ,"Action","Miscellaneous","Role-Playing"
      ,"Adventure","Sports","Driving","Simulation"]
for i in drop:
    generos2.remove(i)
plt.figure(figsize=(12,6))
plt.bar(lista_nueva, cant_repe_generos)
plt.title('Genero y su repeticion')

plt.ylim(0,100
        )

plt.xlabel(1)
plt.ylabel(1)

plt.xticks(rotation=90)
#plt.yticks(rotation=45)
plt.show()
plt.close('all')
# Out:
# ['Breeding/Constructing', 'Survival', 'Japanese-Style', 'Other', 'GT / Street', 'Strategy', 'Card Battle', 'Fantasy', 'Action Adventure', 'Historic', 'Turn-Based', 'Action', 'First-Person', 'Miscellaneous', 'Role-Playing', 'Adventure', 'Shooter', 'Scrolling', 'Real-Time', 'Action RPG', 'Massively Multiplayer Online', 'Sci-Fi', 'Modern', 'Open-World', 'Platformer', 'PC-style RPG', 'City Building', 'Traditional', 'Puzzle', 'Tycoon', '3D', 'Racing', 'Virtual Life', 'Music', 'Fighting', 'Sim', 'Arcade', 'Sports', 'Driving', 'Flight', 'Horror', 'Third-Person', '2D', 'Alternative', "Beat-'Em-Up", 'Military', 'Street', 'General', 'Massively Multiplayer', 'Simulation']

# %% [markdown]
# **CONCLUSIONES??**
