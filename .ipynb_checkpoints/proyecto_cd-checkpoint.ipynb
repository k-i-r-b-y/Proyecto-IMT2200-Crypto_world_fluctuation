# %%
from urllib import response
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **WEBSCRAPPING A METACRITIC**

# %%
pages = [0]
links = []
for i in pages:
    url = f"https://www.metacritic.com/browse/games/score/metascore/all/all/filtered?page={i}"
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(url, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")

    juegos = soup.find_all("td", {"class": "clamp-summary-wrap"})
    for j in juegos:
        a = j.find("a", {"class": "title"})
        l = a["href"]
        link = (f"http://www.metacritic.com{l}")
        links.append(link)

# %% [markdown]
# **Nombres**

# %%
nombres = []
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("div", {"class":"product_title"})
    for p in a:
        nombres.append(p.find("a").text.strip())

# %% [markdown]
# **Ratings (META)**

# %%
ratings = []
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("a",{"class": "metascore_anchor"})
    ratings.append(a[0].text.strip())

# %% [markdown]
# **Plataforma**

# %%
plataforma = []
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("div", {"class":"product_title"})
    for p in a:
        plataforma.append(p.find("span").text.strip())

# %% [markdown]
# **RATING (USERS)**

# %%
rating_user = []
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("a",{"class": "metascore_anchor"})
    rating_user.append(a[1].text.strip())

# %% [markdown]
# **DEVELOPER**

# %%
developers = []
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("span",{"class": "data"})
    for p in a:
        developers.append(p.find("a").text.strip())
        break

# %% [markdown]
# **FECHA**

# %%
date = []
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("li",{"class": "summary_detail release_data"})
    for p in a:
        date.append(p.find("span", {"class":"data"}).text)

# %% [markdown]
# **GENEROS**

# %%
generos = []
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("li",{"class": "summary_detail product_genre"})
    for p in a:
        generos.append(p.find("span", {"class":"data"}).text)

# %% [markdown]
# **RESUMEN**

# %%
resumen = []
for l in range(len(links)):
    resumen.append("")

contador = 0
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("li",{"class": "summary_detail product_summary"})
    for p in a:
        if p.find("span", {"class":"blurb blurb_collapsed"}) == None:
            continue
        else:
            resumen[contador] = (p.find("span", {"class":"blurb blurb_collapsed"}).text.strip())

        
    for p in a:
        if p.find("span", {"class":"data"}) == None:
            continue
        else:
            resumen[contador] = (p.find("span", {"class":"data"}).text.strip())
            
    contador += 1
print(len(resumen))
# Out:
# 100

# %% [markdown]
# **CLASIFICACION**

# %%
clasificacion = []
for l in range(len(links)):
    clasificacion.append("")

contador = 0
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("li",{"class": "summary_detail product_rating"})
    for p in a:
        if p.find("span", {"class":"data"}) == None:
            continue
        else:
            clasificacion[contador] = (p.find("span", {"class":"data"}).text)
    contador += 1

# %% [markdown]
# **numero de jugadores**

# %% [markdown]
# NUlOS = ""

# %%
players = []
for x in range(len(links)):
    players.append("")


contador = 0
for l in links:
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = rq.get(l, headers = user_agent)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find_all("ul",{"class": "summary_details"})
    for p in a:
        b = p.find("li", {"class": "summary_detail product_players"})
        if b == None:
            continue
        else:
            players[contador] = ((b.text.split(":")[1].strip()))
    contador +=1

# %%
df_games = pd.DataFrame()
df_games["Nombre"] = nombres
df_games["Rating_Meta"] = ratings
df_games["Rating_Usuarios"] = rating_user
df_games["Plataforma"] = plataforma
df_games["Developer"] = developers
df_games["Fecha"] = date
df_games["Genero"] = generos
df_games["Resumen"] = resumen
df_games["N_jugadores"] = players
df_games["Clasificacion"] = clasificacion
df_games
# Out:
#                                   Nombre Rating_Meta Rating_Usuarios  \
# 0   The Legend of Zelda: Ocarina of Time          99             9.1
# 1               Tony Hawk's Pro Skater 2          98             7.4
# 2                    Grand Theft Auto IV          98             7.8
# 3                            SoulCalibur          98             8.4
# 4                    Grand Theft Auto IV          98             8.0
# ..                                   ...         ...             ...
# 95           Sid Meier's Civilization II          94             8.8
# 96                                 Quake          94             8.7
# 97        Call of Duty 4: Modern Warfare          94             8.5
# 98                     BioShock Infinite          94             8.6
# 99                                Halo 3          94             8.2
#
#        Plataforma               Developer         Fecha            Genero  \
# 0     Nintendo 64                Nintendo  Nov 23, 1998  Action Adventure
# 1     PlayStation              Activision  Sep 20, 2000            Sports
# 2   PlayStation 3          Rockstar Games  Apr 29, 2008  Action Adventure
# 3       Dreamcast                   Namco  Sep  8, 1999            Action
# 4        Xbox 360          Rockstar Games  Apr 29, 2008  Action Adventure
# ..            ...                     ...           ...               ...
# 95             PC              MicroProse  Feb 29, 1996          Strategy
# 96             PC             id Software  Jun 22, 1996            Action
# 97       Xbox 360              Activision  Nov  5, 2007            Action
# 98             PC                2K Games  Mar 25, 2013            Action
# 99       Xbox 360  Microsoft Game Studios  Sep 25, 2007            Action
#
#                                               Resumen            N_jugadores  \
# 0   As a young boy, Link is tricked by Ganondorf, ...               1 Player
# 1   As most major publishers' development efforts ...                    1-2
# 2   [Metacritic's 2008 PS3 Game of the Year; Also ...               1 Player
# 3   This is a tale of souls and swords, transcendi...                    1-2
# 4   [Metacritic's 2008 Xbox 360 Game of the Year; ...               1 Player
# ..                                                ...                    ...
# 95  An empire-building turn-based strategy game. T...               1 Player
# 96  Rage through 32 single player levels and 6 dea...                   1-16
# 97  As Call of Duty 4: Modern Warfare's single pla...               Up to 18
# 98  Initially conceived as a floating symbol of Am...  No Online Multiplayer
# 99  Halo 3 is the third game in the Halo Trilogy a...                    1-4
#
#    Clasificacion
# 0              E
# 1              T
# 2              M
# 3              T
# 4              M
# ..           ...
# 95           K-A
# 96             M
# 97             M
# 98             M
# 99             M
#
# [100 rows x 10 columns]

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre           100 non-null    object
#  1   Rating_Meta      100 non-null    object
#  2   Rating_Usuarios  100 non-null    object
#  3   Plataforma       100 non-null    object
#  4   Developer        100 non-null    object
#  5   Fecha            100 non-null    object
#  6   Genero           100 non-null    object
#  7   Resumen          100 non-null    object
#  8   N_jugadores      100 non-null    object
#  9   Clasificacion    100 non-null    object
# dtypes: object(10)
# memory usage: 7.9+ KB

# %%
df_games["Fecha"] = pd.to_datetime(df_games["Fecha"])

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre           100 non-null    object
#  1   Rating_Meta      100 non-null    object
#  2   Rating_Usuarios  100 non-null    object
#  3   Plataforma       100 non-null    object
#  4   Developer        100 non-null    object
#  5   Fecha            100 non-null    datetime64[ns]
#  6   Genero           100 non-null    object
#  7   Resumen          100 non-null    object
#  8   N_jugadores      100 non-null    object
#  9   Clasificacion    100 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 7.9+ KB

# %%
df_games.sort_values(by="Fecha")
# Out:
#                          Nombre Rating_Meta Rating_Usuarios     Plataforma  \
# 95  Sid Meier's Civilization II          94             8.8             PC
# 96                        Quake          94             8.7             PC
# 27                GoldenEye 007          96             9.0    Nintendo 64
# 34                     Tekken 3          96             9.0    PlayStation
# 44                 Gran Turismo          96             8.6    PlayStation
# ..                          ...         ...             ...            ...
# 33  Portal Companion Collection          96             8.1         Switch
# 50              Persona 5 Royal          95             8.7             PC
# 94              Persona 5 Royal          94             8.5         Switch
# 83              Persona 5 Royal          94             8.4  Xbox Series X
# 82         God of War: Ragnarok          94             8.3  PlayStation 5
#
#               Developer      Fecha         Genero  \
# 95           MicroProse 1996-02-29       Strategy
# 96          id Software 1996-06-22         Action
# 27             Nintendo 1997-08-25         Action
# 34                Namco 1998-04-29         Action
# 44                 SCEA 1998-04-30        Driving
# ..                  ...        ...            ...
# 33       Valve Software 2022-06-28  Miscellaneous
# 50                 Sega 2022-10-21   Role-Playing
# 94                 Sega 2022-10-21   Role-Playing
# 83                 Sega 2022-10-21   Role-Playing
# 82  PlayStation Studios 2022-11-09     Open-World
#
#                                               Resumen            N_jugadores  \
# 95  An empire-building turn-based strategy game. T...               1 Player
# 96  Rage through 32 single player levels and 6 dea...                   1-16
# 27  You are Bond. James Bond. You are assigned cov...                    1-4
# 34  An ancient evil force has reawakened, attackin...                    1-2
# 44  Welcome to the most advanced racing game ever ...                    1-2
# ..                                                ...                    ...
# 33  Including Portal and Portal 2, the Companion C...
# 50  Prepare for an all-new RPG experience in Perso...  No Online Multiplayer
# 94  Forced to transfer to a high school in Tokyo, ...  No Online Multiplayer
# 83  Prepare for an all-new RPG experience in Perso...  No Online Multiplayer
# 82  The freezing winds of Fimbulwinter have come t...  No Online Multiplayer
#
#    Clasificacion
# 95           K-A
# 96             M
# 27             T
# 34             T
# 44             E
# ..           ...
# 33
# 50             M
# 94             M
# 83             M
# 82             M
#
# [100 rows x 10 columns]
